# %% [markdown]
# <a href="https://colab.research.google.com/github/ibtissam01/Portugal_student/blob/main/IBTISSAM_LABYADY_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Read and Describe Data

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f764539-4b13-4049-b77f-7262c85bc6f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f764539-4b13-4049-b77f-7262c85bc6f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving student-por.csv to student-por (2).csv

# %%
data=pd.read_csv(r'student-por.csv')
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data=pd.read_csv(r'C:\Users\Massitbi\Downloads\student-por.csv')
data.head()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
col=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu','Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime','failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery','higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc','Walc', 'health', 'absences', 'G1', 'G2', 'G3']

# %%
def valuecount(l,data):
  for i in l:
    print("______________________________________________")
    print('les distincts elements et occurences  de ', i)
    print( data[i].value_counts())

# %%
valuecount(col,data)
# Out:
# ______________________________________________
# les distincts elements et occurences  de  school
# GP    423
# MS    226
# Name: school, dtype: int64
# ______________________________________________
# les distincts elements et occurences  de  sex
# F    383
# M    266
# Name: sex, dtype: int64
# ______________________________________________
# les distincts elements et occurences  de  age
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: age, dtype: int64
# ______________________________________________
# les distincts elements et occurences  de  address
# U    452
# R    197
# Name: address, dtype: int64
# ______________________________________________
# les distincts elements et occurences  de  famsize
# GT3    457
# LE3    192
# Name: famsize, dtype: int64
# ______________________________________________
# les distincts elements et occurences  de  Pstatus
# T    569
# A     80
# Name: Pstatus, dtype: int64
# ...

# %% [markdown]
# #Handling Missing Data

# %%
data.dropna()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
data.dropna().shape
# Out:
# (649, 33)

# %% [markdown]
# #Filter

# %% [markdown]
# Nous souhaitons garder seulement les eleves ayant entre 15 et 19

# %%
def filter_fun(df,str):
  return df[str] < 20

data1=filter_fun(data,"age")
data1=data.loc[data1]

# %% [markdown]
# #Group Operations

# %%
tips_gb = data1.groupby([ 'school','sex'])
tips_gb

# %%
tips_agg = tips_gb.agg({
    'G3': [ 'min', 'max'],

})

tips_agg
# Out:
#             G3
#            min max
# school sex
# GP     F     7  19
#        M     0  18
# MS     F     0  18
#        M     0  19

# %% [markdown]
# #Conditional Selection

# %% [markdown]
# creating catagorie columns list and numeric columns list

# %%
numeric=data1.select_dtypes(include=['int64']).columns.values
numeric
# Out:
# array(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures',
#        'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health',
#        'absences', 'G1', 'G2', 'G3'], dtype=object)

# %%
categorie = (data1.select_dtypes(include=['object']).columns.values)
categorie
# Out:
# array(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'], dtype=object)

# %%
numeric[0]
# Out:
# 'age'

# %% [markdown]
# # DAta Statistic

# %%
data1.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  640.000000  640.000000  640.000000  640.000000  640.000000  640.000000
# mean    16.692187    2.520313    2.317188    1.567187    1.932813    0.206250
# std      1.141315    1.134007    1.095310    0.751744    0.829909    0.571596
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     19.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  640.000000  640.000000  640.000000  640.000000  640.000000  640.000000
# mean     3.932812    3.179688    3.189062    1.493750    2.276562    3.535938
# ...

# %% [markdown]
# #visualisation

# %%
plt.bar([1,3,5,7,9],[5,2,7,8,2], label="School one")
plt.bar([2,4,6,8,10],[8,6,2,5,6], label="School two", color='g')
plt.legend()
plt.xlabel('bar number')
plt.ylabel('bar height')

plt.title('Epic Graph\nAnother Line! Whoa')

plt.show()

# %%
numeric = ['age', 'Medu', 'Fedu', 'traveltime', 'studytime','failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
DS=data1[(data1['school']=='MS')]
DS[numeric].hist(figsize=(20,17))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f823a7558d0>,
# ...
#       dtype=object)

# %%
DSG=data1[(data1['school']=='GP')]
DSG[numeric].hist(figsize=(20,17))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8239ef7750>,
# ...
#       dtype=object)

# %%
def graphepie(numeric):
  explode=[]
  for i in numeric:
    data2=data1.loc[(data1["sex"]=='F'),[i]]
    data3=data2.value_counts()
    labels=data1[i].unique()
    explode=[0*i for i in range(len(data3))]
    explode[0]=0.08
    plt.pie(data3, explode=explode)
    plt.show()

# %% [markdown]
# In this section my goal is to explore relationships of 2 columns with each other, our main focus are the exam result so I'll focus more in the relation ship of different columns with exam results,Comparing exam score mean for each columns

# %% [markdown]
# We can see some distribution difference from the exam score distribution, for example:
# The exam mean value seems to have a inverse relationship with alcoholic consumption
# The exam mean increases with increasing study time and score distribution tend to shift slightly to the right
# The exam mean increases from other student if Mother of Father works as a teacher and score distribution tend to shift slightly to the right
# The distribution health shift to left (score decreases) if health of the student is worse
# The exam mean is worst if the guardian of the student is other than father or mother, there are some difference between guardian being the father and the mother, but the entries of father being the guardian is significantly smaller than the mother as most students have there mother as guardian
